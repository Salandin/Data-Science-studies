# %% [markdown]
# Biblioteca Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
base = pd.read_csv('trees.csv')
base
# Out:
#     Girth  Height  Volume
# 0     8.3      70    10.3
# 1     8.6      65    10.3
# 2     8.8      63    10.2
# 3    10.5      72    16.4
# 4    10.7      81    18.8
# 5    10.8      83    19.7
# 6    11.0      66    15.6
# 7    11.0      75    18.2
# 8    11.1      80    22.6
# 9    11.2      75    19.9
# 10   11.3      79    24.2
# 11   11.4      76    21.0
# 12   11.4      76    21.4
# 13   11.7      69    21.3
# 14   12.0      75    19.1
# 15   12.9      74    22.2
# 16   12.9      85    33.8
# 17   13.3      86    27.4
# 18   13.7      71    25.7
# 19   13.8      64    24.9
# 20   14.0      78    34.5
# 21   14.2      80    31.7
# 22   14.5      74    36.3
# 23   16.0      72    38.3
# 24   16.3      77    42.6
# 25   17.3      81    55.4
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %% [markdown]
# Boxplot

# %%
sea.boxplot(base.Volume).set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
sea.boxplot( data=base)

# %% [markdown]
# Histogramas e Densidade

# %%
#histograma com 10 divisões
sea.distplot(base.Volume, bins=10, axlabel='Volume').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
#carregamento de outra base de dados
base2 = pd.read_csv('chicken.csv')
base2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
agrupado = base2.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
teste = base2.loc[base2['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
#histograma considerando apenas o horsebean
sea.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist=False).set_title('horsebean')
# Out:
# Text(0.5, 1.0, 'horsebean')

# %%
#histograma considerando apenas o casein
sea.distplot(base2.loc[base2['feed'] == 'casein'].weight, hist=False).set_title('casein')
# Out:
# Text(0.5, 1.0, 'casein')

# %%
#histograma considerando apenas o meatmeal
sea.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight, hist=False).set_title('meatmeal')
# Out:
# Text(0.5, 1.0, 'meatmeal')

# %%
#histograma considerando apenas o soybean
sea.distplot(base2.loc[base2['feed'] == 'soybean'].weight, hist=False).set_title('soybean')
# Out:
# Text(0.5, 1.0, 'soybean')

# %%
#histograma considerando apenas o sunflower
sea.distplot(base2.loc[base2['feed'] == 'sunflower'].weight, hist=False).set_title('sunflower')
# Out:
# Text(0.5, 1.0, 'sunflower')

# %%
#impressão grafica 2x3
plt.figure()
plt.subplot(3,2,1)
sea.distplot(base2.loc[base2['feed'] == 'horsebean'].weight, hist=False).set_title('horsebean')
plt.subplot(3,2,2)
sea.distplot(base2.loc[base2['feed'] == 'casein'].weight, hist=False).set_title('casein')
plt.subplot(3,2,3)
sea.distplot(base2.loc[base2['feed'] == 'meatmeal'].weight, hist=False).set_title('meatmeal')
plt.subplot(3,2,4)
sea.distplot(base2.loc[base2['feed'] == 'soybean'].weight, hist=False).set_title('soybean')
plt.subplot(3,2,5)
sea.distplot(base2.loc[base2['feed'] == 'sunflower'].weight, hist=False).set_title('sunflower')
plt.tight_layout()

# %% [markdown]
# Grafico de Dispersão

# %%
base3 = pd.read_csv('co2.csv')
base3.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
sea.scatterplot(base3.conc , base3.uptake, hue = base3.Type)

# %%
q = base3.loc[base3['Type'] == 'Quebec']
m = base3.loc[base3['Type'] == 'Mississippi']

# %%
plt.figure()
plt.subplot(1,2,1)
sea.scatterplot(q.conc, q.uptake).set_title('Quebec')
plt.subplot(1,2,2)
sea.scatterplot(m.conc, m.uptake).set_title('Mississippi')
plt.tight_layout()

# %%
#Refrigerado/não refrigerado
ch = base3.loc[base3['Treatment'] == 'chilled']
nc = base3.loc[base3['Treatment'] == 'nonchilled']

# %%
plt.figure()
plt.subplot(2,2,1)
sea.scatterplot(ch.conc, ch.uptake).set_title('chilled')
plt.subplot(1,2,2)
sea.scatterplot(nc.conc, nc.uptake).set_title('nonchilled')
plt.tight_layout()

# %%
base4 = pd.read_csv('esoph.csv')
base4
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# entre os elementos sem agrupamento
sea.catplot(x='alcgp', y='ncontrols', data=base4, jitter=False)

# %%
# entre os elementos com agrupamento
sea.catplot(x='alcgp', y='ncontrols', data=base4, col='tobgp')
